# %% [markdown]
# # Análisis Exploratorio de los Contratos

# %%
import pandas as pd
import numpy as np

# %%
sanciones = pd.read_csv('Datos/Multas_y_Sanciones_SECOP_I.csv')

# %%
contratos = pd.read_csv('Datos/secop_ips_i_limpia.gz')

# %%
sanciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401 entries, 0 to 1400
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nombre Entidad         1401 non-null   object
#  1   NIT Entidad            961 non-null    object
#  2   Nivel                  1401 non-null   object
#  3   Orden                  1401 non-null   object
#  4   Municipio              1401 non-null   int64
#  5   Numero de Resolucion   1401 non-null   object
#  6   Documento Contratista  1401 non-null   object
#  7   Nombre Contratista     1400 non-null   object
#  8   Numero de Contrato     1400 non-null   object
#  9   Valor Sancion          1401 non-null   float64
#  10  Fecha de Publicacion   1401 non-null   object
#  11  Ruta de Proceso        1401 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 131.5+ KB

# %%
sanciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401 entries, 0 to 1400
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nombre Entidad         1401 non-null   object
#  1   NIT Entidad            961 non-null    object
#  2   Nivel                  1401 non-null   object
#  3   Orden                  1401 non-null   object
#  4   Municipio              1401 non-null   int64
#  5   Numero de Resolucion   1401 non-null   object
#  6   Documento Contratista  1401 non-null   object
#  7   Nombre Contratista     1400 non-null   object
#  8   Numero de Contrato     1400 non-null   object
#  9   Valor Sancion          1401 non-null   float64
#  10  Fecha de Publicacion   1401 non-null   object
#  11  Ruta de Proceso        1401 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 131.5+ KB

# %%
contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1391448 entries, 0 to 1391447
# Data columns (total 46 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   anno_cargue                       1391448 non-null  int64
#  1   anno_firma                        1391448 non-null  float64
#  2   nivel_entidad                     1391448 non-null  object
#  3   orden_entidad                     1391448 non-null  object
#  4   nombre_entidad                    1391448 non-null  object
#  5   nit_entidad                       1391448 non-null  object
#  6   tipo_proceso                      1391448 non-null  object
#  7   estado_proceso                    1391448 non-null  object
#  8   causa_otras_formas_contr_directa  1391448 non-null  object
#  9   regimen_contratacion              1391448 non-null  object
#  10  objeto_contratar                  1391448 non-null  object
# ...

# %%
contratos.groupby('objeto_contratar').size().sort_values(ascending=False)
# Out:
# objeto_contratar
# Servicios de Salud                                                                                            633830
# Servicios de Gestion, Servicios Profesionales de Empresa y Servicios Administrativos                          280137
# Equipo Médico, Accesorios y Suministros                                                                       129134
# Medicamentos y Productos Farmacéuticos                                                                         81727
# Servicios de Limpieza, Descontaminación y Tratamiento de Residuos                                              19854
# Servicios de Transporte, Almacenaje y Correo                                                                   19686
# Equipos de Oficina, Accesorios y Suministros                                                                   18524
# Servicios de Edificación, Construcción de Instalaciones y Mantenimiento                                        17547
# ...

# %%
contratos_medicamentos = contratos.loc[contratos['objeto_contratar'] == 'Medicamentos y Productos Farmacéuticos']
contratos_medicamentos
# Out:
#          anno_cargue  anno_firma nivel_entidad  \
# 49              2015      2015.0   TERRITORIAL
# 116             2020      2020.0   TERRITORIAL
# 119             2019      2019.0   TERRITORIAL
# 127             2014      2014.0   TERRITORIAL
# 136             2014      2014.0   TERRITORIAL
# ...              ...         ...           ...
# 1391387         2018      2018.0   TERRITORIAL
# 1391390         2018      2018.0   TERRITORIAL
# 1391396         2019      2019.0   TERRITORIAL
# 1391406         2018      2018.0   TERRITORIAL
# 1391434         2016      2016.0   TERRITORIAL
#
#                                      orden_entidad  \
# 49       TERRITORIAL DEPARTAMENTAL DESCENTRALIZADO
# 116      TERRITORIAL DEPARTAMENTAL DESCENTRALIZADO
# 119        TERRITORIAL DISTRITAL MUNICIPAL NIVEL 2
# 127      TERRITORIAL DEPARTAMENTAL DESCENTRALIZADO
# 136      TERRITORIAL DEPARTAMENTAL DESCENTRALIZADO
# ...                                            ...
# ...

# %%
contratos_medicamentos = contratos_medicamentos.loc[contratos_medicamentos.cuantia_contrato > 1e8].shape
